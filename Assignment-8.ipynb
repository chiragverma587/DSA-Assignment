# %%
1.def minimumDeleteSum(s1, s2):
    m, n = len(s1), len(s2)
    # Create a 2D array to store the minimum ASCII sum
    dp = [[0] * (n + 1) for _ in range(m + 1)]

    # Fill the first row and column with ASCII sums
    for i in range(1, m + 1):
        dp[i][0] = dp[i - 1][0] + ord(s1[i - 1])
    for j in range(1, n + 1):
        dp[0][j] = dp[0][j - 1] + ord(s2[j - 1])

    # Fill the remaining cells
    for i in range(1, m + 1):
        for j in range(1, n + 1):
            if s1[i - 1] == s2[j - 1]:
                dp[i][j] = dp[i - 1][j - 1]
            else:
                dp[i][j] = min(dp[i - 1][j] + ord(s1[i - 1]),  # Delete s1[i]
                               dp[i][j - 1] + ord(s2[j - 1]))  # Delete s2[j]

    return dp[m][n]

# %%
2.def checkValidString(s):
    stack = []
    star_stack = []
    
    for i, char in enumerate(s):
        if char == '(':
            stack.append(i)
        elif char == '*':
            star_stack.append(i)
        else:  # char == ')'
            if stack:
                stack.pop()
            elif star_stack:
                star_stack.pop()
            else:
                return False
    
    while stack and star_stack:
        if stack[-1] > star_stack[-1]:
            return False
        stack.pop()
        star_stack.pop()
    
    return len(stack) == 0

# %%
3.def minDistance(word1, word2):
    m, n = len(word1), len(word2)

    # Create a 2D array to store the lengths of LCS
    dp = [[0] * (n + 1) for _ in range(m + 1)]

    # Fill the array using dynamic programming approach
    for i in range(1, m + 1):
        for j in range(1, n + 1):
            if word1[i - 1] == word2[j - 1]:
                dp[i][j] = dp[i - 1][j - 1] + 1
            else:
                dp[i][j] = max(dp[i - 1][j], dp[i][j - 1])

    lcs_length = dp[m][n]
    min_steps = m + n - 2 * lcs_length

    return min_steps

# %%
4.class TreeNode:
    def __init__(self, value):
        self.val = value
        self.left = None
        self.right = None


def str2tree(s):
    if not s:
        return None

    # Find the value of the root node
    i = 0
    while i < len(s) and (s[i].isdigit() or s[i] == '-'):
        i += 1
    value = int(s[:i])
    root = TreeNode(value)

    # Find the substring representing the left child
    left_start = i
    left_end = find_matching_parenthesis(s, left_start)
    root.left = str2tree(s[left_start + 1: left_end])

    # Find the substring representing the right child
    right_start = left_end + 1
    right_end = find_matching_parenthesis(s, right_start)
    root.right = str2tree(s[right_start + 1: right_end])

    return root


def find_matching_parenthesis(s, start):
    count = 0
    for i in range(start, len(s)):
        if s[i] == '(':
            count += 1
        elif s[i] == ')':
            count -= 1
        if count == 0:
            return i
    return -1

# %%
5.def compress(chars):
    write_index = 0  # Pointer to track the position to write the compressed characters
    count = 1  # Count of consecutive repeating characters

    for i in range(1, len(chars) + 1):
        if i < len(chars) and chars[i] == chars[i - 1]:
            count += 1
        else:
            chars[write_index] = chars[i - 1]
            write_index += 1

            if count > 1:
                count_str = str(count)
                for j in range(len(count_str)):
                    chars[write_index] = count_str[j]
                    write_index += 1

            count = 1

    return write_index

# %%
6.from collections import Counter

def findAnagrams(s, p):
    result = []
    len_s, len_p = len(s), len(p)

    # Create frequency maps for p and the sliding window in s
    freq_p = Counter(p)
    freq_window = Counter()

    # Initialize the sliding window
    window_start = 0
    window_end = 0

    while window_end < len_s:
        # Expand the sliding window
        freq_window[s[window_end]] += 1

        # Shrink the sliding window if its size exceeds len_p
        if window_end - window_start + 1 > len_p:
            freq_window[s[window_start]] -= 1
            if freq_window[s[window_start]] == 0:
                del freq_window[s[window_start]]
            window_start += 1

        # Check if the current window is an anagram of p
        if freq_window == freq_p:
            result.append(window_start)

        window_end += 1

    return result

# %%
7.def decodeString(s):
    stack = []
    
    for char in s:
        if char != ']':
            stack.append(char)
        else:
            # Find the encoded string
            encoded_string = ''
            while stack[-1] != '[':
                encoded_string = stack.pop() + encoded_string
            stack.pop()  # Discard the '[' character
            
            # Find the repetition count
            count = ''
            while stack and stack[-1].isdigit():
                count = stack.pop() + count
            
            # Repeat the encoded string and push it back to the stack
            stack.append(int(count) * encoded_string)
    
    return ''.join(stack)

# %%
8.def buddyStrings(s, goal):
    if len(s) != len(goal):
        return False
    
    if s == goal:
        # Check if there are at least two repeated characters
        return len(set(s)) < len(s)
    
    differences = []
    for i in range(len(s)):
        if s[i] != goal[i]:
            differences.append(i)
    
    return len(differences) == 2 and s[differences[0]] == goal[differences[1]] and s[differences[1]] == goal[differences[0]]
